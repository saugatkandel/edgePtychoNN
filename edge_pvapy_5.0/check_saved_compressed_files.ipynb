# %%
import numpy as np
import blosc2
import matplotlib.pyplot as plt

# %%
idata = 'data/inputs/000001.1.bl2'

# %%
odata = 'data/inferences/000001.1.bl2'

# %%
iarr = blosc2.load_array(idata)

# %%
oarr = blosc2.load_array(odata)

# %%
plt.imshow(iarr)

# %%
plt.imshow(oarr)
plt.colorbar()
